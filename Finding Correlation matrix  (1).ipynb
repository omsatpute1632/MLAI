# %%
#Name:Om V. Satpute
#sec:c
#sub:MLAI

# %%
#importing the basic library
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\omsat\\Downloads'

# %%
data=pd.read_csv("C:\\Users\\omsat\\Desktop\\salary_data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.shape
# Out:
# (30, 2)

# %%
data.size
# Out:
# 60

# %%
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.isna()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
data.isna().any()
# Out:
# YearsExperience    False
# Salary             False
# dtype: bool

# %%
data.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#correlation
corr = data.corr()

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,6))
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >
